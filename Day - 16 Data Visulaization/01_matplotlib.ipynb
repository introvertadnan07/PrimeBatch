# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
x = [1, 2, 3, 4]
y = [5, 6, 7, 8]

plt.plot(x, y)
plt.show()

# %% [markdown]
# # Real data

# %%
# Oscar Winner Movies
oscar_movies = [
    "The Dark Knight", 
    "The Hurt Locker",  
    "The King's Speech", 
    "The Artist",     
    "Argo"
]
oscar_years = [2008, 2009, 2010, 2011, 2012]
oscar_revenue = [1005, 170, 427, 133, 232]  # in $M

plt.plot(oscar_years, oscar_revenue)
plt.title("Oscar Years vs Revenue(in $M)")
plt.xlabel("Years")
plt.ylabel("Revenue(in $M)")
plt.show()

# %%
# Plot multiple
# Non-Oscar Winner Movies
non_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_years = [2008, 2009, 2010, 2011, 2012]
non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

plt.plot(oscar_years, oscar_revenue, label="Oscar Winners")
plt.plot(non_oscar_years, non_oscar_revenue, label="Non-Oscar Winners")
plt.title("Years vs Revenue(in $M)")
plt.xlabel("Years")
plt.ylabel("Revenue(in $M)")
plt.legend()
plt.show()
# plt.legend(loc="upper right")
# plt.legend(loc="upper left")
# plt.legend(loc="center")

# %%
# using Format Strings
plt.plot(oscar_years, oscar_revenue, "o-b", label="Oscar Winners")
plt.plot(non_oscar_years, non_oscar_revenue, ">--g", label="Non-Oscar Winners")

plt.plot(oscar_years, oscar_revenue, color="black", linestyle="-", marker="o",label="Oscar Winners")
plt.plot(non_oscar_years, non_oscar_revenue, color="red", linestyle="--", marker=">", linewidth=5, label="Non-Oscar Winners")
plt.show()

# %%
# Other Methods & Attributes
print(plt.style.available)
plt.plot(oscar_years, oscar_revenue, label="Oscar Winners")
plt.style.use('dark_background')
plt.style.use('ggplot')

plt.grid(True)

with plt.xkcd():
    plt.plot(oscar_years, oscar_revenue, "o-b", label="Oscar Winners")
    plt.plot(non_oscar_years, non_oscar_revenue, ">--g", label="Non-Oscar Winners")
    plt.xlabel("Years")
    plt.ylabel("Revenue(in $M)")
    plt.legend()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.

# %%
# Oscar Winner Movies
movies = [
    "The Dark Knight", 
    "The Hurt Locker",  
    "The King's Speech", 
    "The Artist",     
    "Argo"
]
years = [2008, 2009, 2010, 2011, 2012]
revenue = [1005, 170, 427, 133, 232]  # in $M

plt.plot(movies, revenue)
plt.title("Movies Revenue")
plt.xlabel("Movies")
plt.ylabel("Revenue($M")

plt.tight_layout()
plt.savefig("final_plot.png")

# %%
# Bar Charts
movies = [
    "The Dark Knight", 
    "The Hurt Locker",  
    "The King's Speech", 
    "The Artist",     
    "Argo"
]
years = [2008, 2009, 2010, 2011, 2012]
oscar_revenue = [1005, 170, 427, 133, 232]  # in $M

plt.bar(years, oscar_revenue)
plt.title("Revenue in each year")
plt.xlabel("Year")
plt.ylabel("Revenue in $M")

for i in range(len(years)):
    plt.text(years[i], oscar_revenue[i]+15,str( oscar_revenue[0]), ha="center")
plt.savefig("bar_plot.png")
plt.show()

# %%
# comparing data with bar charts
oscar_movies = ["The Dark Knight","The Hurt Locker","The King's Speech","The Artist","Argo"]
oscar_revenue = [1005, 170, 427, 133, 232]  # in $M

non_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

years = [2008, 2009, 2010, 2011, 2012]

# Plotting Bar Chart
import numpy as np
x = np.arange(len(years))
width = 0.4

plt.bar(x-width/2, oscar_revenue, width, label="Oscar")
plt.bar(x+width/2, non_oscar_revenue, width, label="Non-Oscar")

plt.xlabel("Years")
plt.ylabel("Revenue (in $M)")
plt.title("Yearly revenue of Oscar vs Non-Oscar movies")
plt.legend()
plt.tight_layout()

plt.xticks(x, years) # to show x-axis labels
plt.savefig("caparing_data.png")

# %%
# Horizontal Bar Chart
oscar_movies = ["The Dark Knight","The Hurt Locker","The King's Speech","The Artist","Argo"]
oscar_revenue = [1005, 170, 427, 133, 232]  # in $M

non_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

years = [2008, 2009, 2010, 2011, 2012]

# Plotting
# y = np.arange(len(years))
plt.barh(oscar_movies, oscar_revenue)
plt.xlabel("Revenue")
plt.ylabel("Movie")
plt.title("Revenue for each Movie")
plt.savefig("horizontal.png")

# %%
# Scatter Plots
people = ["Person A", "Person B", "Person C", "Person D", "Person E", 
          "Person F", "Person G", "Person H", "Person I", "Person J"]
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
blood_pressure = [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]

# plot
# plt.scatter(age, blood_pressure, color="red")

plt.title("Age vs Blood Pressure")
plt.xlabel("Age")
plt.ylabel("Blood Pressure")
plt.grid()

# Customizing plots
colors = ["green" if bp<135 else "red" for bp in blood_pressure]
sizes = blood_pressure
plt.scatter(age, blood_pressure, color=colors, s=sizes, marker='^', alpha=0.5)

# plt.scatter(age, blood_pressure, c=blood_pressure, cmap="plasma")
plt.scatter(age, blood_pressure, c=blood_pressure, cmap="OrRd")# makes more sense
# plt.scatter(age, blood_pressure, c=[5]*len(age), cmap="plasma")
plt.colorbar(label="BP")

for i in range(len(age)):
    plt.annotate(people[i], xy=(age[i], blood_pressure[i]))
plt.xlim(min(age), max(age)+10)
plt.savefig("scatter_plot.png")
plt.show()

# %%
# Multiple scatter plots
cities = ["City A", "City B", "City C", "City D", "City E"]

# Winter: Temperature (°C) vs Humidity (%)
winter_temp = [5, 2, 10, 0, 7]
winter_humidity = [80, 75, 65, 85, 70]

# Summer: Temperature (°C) vs Humidity (%)
summer_temp = [25, 30, 28, 35, 27]
summer_humidity = [60, 50, 55, 45, 65]

# Plots
plt.scatter(winter_temp, winter_humidity, color="blue", label="Winter")
plt.scatter(summer_temp, summer_humidity, color="orange", label="Summer")

plt.xlabel("Temperature (°C)")
plt.ylabel("Humidity (%)")
plt.legend()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

angles = [90, 180]
titles = ["Start Angle = 90°", "Start Angle = 180°"]

for ax, angle, title in zip(axes, angles, titles):
    ax.pie(
        amounts,
        labels=[f"{e}\n{a/sum(amounts)*100:.1f}%" for e, a in zip(expenses, amounts)],
        colors=colors,
        explode=explode,
        startangle=angle,
        shadow=True,
        labeldistance=0.6,                 # text inside slices
        wedgeprops={"edgecolor": "white"}
    )
    ax.set_title(title)
    ax.axis("equal")

plt.show()

# %%
import matplotlib.pyplot as plt

expenses = ["Salaries", "Rent", "Marketing", "R&D", "Miscellaneous"]
amounts = [500, 150, 120, 100, 50]
colors = ["pink", "green", "blue", "brown", "red"]

# Explode (Marketing & R&D)
explode = [0, 0, 0, 0, 0.3]

plt.figure(figsize=(7, 7))

plt.pie(
    amounts,
    labels=[f"{e}\n{a/sum(amounts)*100:.1f}%" for e, a in zip(expenses, amounts)],
    colors=colors,
    explode=explode,
    startangle=90,
    shadow=True,
    labeldistance=0.6,                # keeps text inside
    wedgeprops={"edgecolor": "white"}
)

plt.title("Company Expense Distribution")
plt.axis("equal")
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
labels = ["Batman", "Superman", "Iron Man", "Captain America"]
values = [41, 13, 27, 19]
colors = ["gold", "gray", "orange", "skyblue"]

plt.figure(figsize=(6, 6))

# Custom function to show name + %
def make_label(pct, allvals):
    absolute = int(round(pct))
    return f"{absolute}%"

plt.pie(
    values,
    labels=labels,
    colors=colors,
    autopct="%1.0f%%",
    startangle=90,
    textprops={"fontsize": 10},
    wedgeprops={"edgecolor": "white"}
)

plt.title("Superhero Battle Winner")
plt.axis("equal")
plt.show()

# %%
plt.figure(figsize=(6, 6))

plt.pie(
    values,
    labels=[f"{l}\n{v}%" for l, v in zip(labels, values)],
    colors=colors,
    startangle=90,
    labeldistance=0.6,
    wedgeprops={"edgecolor": "white"}
)

plt.title("Superhero Battle Winner")
plt.axis("equal")
plt.show()
